# %% [markdown]
# # Dataset : Corona_virus

# %%
import pandas as pd

# %%
df=pd.read_csv("C:/Users/perfect/Downloads/Python_projects/Python_projects/Corona_virus_analyst_project/covid_19_data.csv")

# %%
df.head()
# Out:
#    SNo ObservationDate Province/State  Country/Region      Last Update  \
# 0    1      01/22/2020          Anhui  Mainland China  1/22/2020 17:00
# 1    2      01/22/2020        Beijing  Mainland China  1/22/2020 17:00
# 2    3      01/22/2020      Chongqing  Mainland China  1/22/2020 17:00
# 3    4      01/22/2020         Fujian  Mainland China  1/22/2020 17:00
# 4    5      01/22/2020          Gansu  Mainland China  1/22/2020 17:00
#
#    Confirmed  Deaths  Recovered
# 0        1.0     0.0        0.0
# 1       14.0     0.0        0.0
# 2        6.0     0.0        0.0
# 3        1.0     0.0        0.0
# 4        0.0     0.0        0.0

# %%
# Analyse the data and give the answers of below questions :
#1.What is the total number of confirmed cases worldwide?
df['Confirmed'].sum()
# Out:
# 26252051758.0

# %%
# 2.How many deaths have been reported globally?
df['Deaths'].sum()
# Out:
# 624013017.0

# %%
# 3.What is the total number of recovered cases worldwide?
df['Recovered'].sum()
# Out:
# 15450237912.0

# %%
# 4.How many countries/regions are represented in the dataset?
df['Country/Region'].nunique()
# Out:
# 229

# %%
import matplotlib.pyplot as plt

# %%
# 5.What is the trend of confirmed cases over time globally?
global_trend=df.groupby(by='ObservationDate')['Confirmed'].sum()
plt.figure(figsize=(12, 6))
plt.plot(global_trend.index, global_trend.values, marker='o', linestyle='-', color='b')
plt.title('Global Trend of Confirmed COVID-19 Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Confirmed Cases')
plt.grid(True)
plt.show()

# %%
# 6.Which province/state has reported the highest number of confirmed cases?
a=df.groupby(by='Province/State')['Confirmed'].sum().idxmax()
b=df.groupby(by='Province/State')['Confirmed'].sum().max()
print(a,b)
# Out:
# California 696898013.0

# %%
# 7.Which country/region has the highest number of deaths?
a=df.groupby(by='Country/Region')['Deaths'].sum().idxmax()
b=df.groupby(by='Country/Region')['Deaths'].sum().max()
print(a,b)
# Out:
# US 123303762.0

# %%
# 8.How does the number of confirmed cases vary across different provinces/states?
confirmed_by_province = df.groupby('Province/State')['Confirmed'].sum()
print("Confirmed cases by province/state:", confirmed_by_province)
# Out:
# Confirmed cases by province/state: Province/State
#  Montreal, QC                17.0
#  Norfolk County, MA           7.0
# Abruzzo                10889970.0
# Acre                   14897611.0
# Adygea Republic         3012608.0
#                           ...
# Zaporizhia Oblast      13858457.0
# Zeeland                 3454955.0
# Zhejiang                 620252.0
# Zhytomyr Oblast        11740027.0
# Zuid-Holland           55835700.0
# Name: Confirmed, Length: 736, dtype: float64

# %%
# 9.What is the trend of deaths over time globally?
global_trend=df.groupby(by='ObservationDate')['Deaths'].sum()
plt.figure(figsize=(12, 6))
plt.plot(global_trend.index, global_trend.values, marker='o', linestyle='-', color='b')
plt.title('Global Trend of Deaths Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Deaths Cases')
plt.grid(True)
plt.show()

# %%
# 10.Which country/region has the highest number of recovered cases?
a=df.groupby(by='Country/Region')['Recovered'].sum().idxmax()
b=df.groupby(by='Country/Region')['Recovered'].sum().max()
print(a,b)
# Out:
# India 2900589824.0

# %%
# 11.How does the number of recovered cases vary across different countries/regions?
recovered_by_country = df.groupby('Country/Region')['Recovered'].sum()
print("Recovered cases by country/region:", recovered_by_country)
# Out:
# Recovered cases by country/region: Country/Region
#  Azerbaijan                              0.0
# ('St. Martin',)                          0.0
# Afghanistan                       13464399.0
# Albania                           13945256.0
# Algeria                           18959299.0
#                                      ...
# West Bank and Gaza                37003116.0
# Yemen                               506523.0
# Zambia                            12625626.0
# Zimbabwe                           5594887.0
# occupied Palestinian territory           0.0
# Name: Recovered, Length: 229, dtype: float64

# %%
# 12.What is the distribution of confirmed cases by country/region?
confirmed_cases_by_country = df.groupby('Country/Region')['Confirmed'].sum().sort_values(ascending=False)

# Plot the confirmed cases distribution as a pie chart
plt.figure(figsize=(10, 10))
confirmed_cases_by_country.plot(kind='pie', autopct='%1.1f%%', startangle=140, colormap='tab20')
plt.title('Distribution of Confirmed COVID-19 Cases by Country/Region')
plt.ylabel('')
plt.show()

# %%
# 13.Is there a correlation between the number of confirmed cases and deaths?
df[['Confirmed','Deaths']].corr()
# Out:
#            Confirmed    Deaths
# Confirmed   1.000000  0.888416
# Deaths      0.888416  1.000000

# %%
# 14.Is there a correlation between the number of confirmed cases and recovered cases?
df[['Confirmed','Recovered']].corr()
# Out:
#            Confirmed  Recovered
# Confirmed   1.000000   0.633479
# Recovered   0.633479   1.000000

# %%
# 15.How does the mortality rate vary across different countries/regions?
df['MortalityRate'] = df['Deaths'] / df['Confirmed']
mortality_rate_by_country = df.groupby('Country/Region')['MortalityRate'].mean()
print(mortality_rate_by_country)
# Out:
# Country/Region
#  Azerbaijan                       0.000000
# ('St. Martin',)                   0.000000
# Afghanistan                       0.034369
# Albania                           0.025761
# Algeria                           0.044855
#                                     ...
# West Bank and Gaza                0.008451
# Yemen                             0.246477
# Zambia                            0.018562
# Zimbabwe                          0.045767
# occupied Palestinian territory    0.000000
# Name: MortalityRate, Length: 229, dtype: float64

# %%
# 16.How does the recovery rate vary across different countries/regions?
df['RecoveryRate'] = df['Recovered'] / df['Confirmed']
recovery_rate_by_country = df.groupby('Country/Region')['RecoveryRate'].mean()
print("Recovery rate by country/region:", recovery_rate_by_country)
# Out:
# Recovery rate by country/region: Country/Region
#  Azerbaijan                       0.000000
# ('St. Martin',)                   0.000000
# Afghanistan                       0.618353
# Albania                           0.596064
# Algeria                           0.605506
#                                     ...
# West Bank and Gaza                0.707508
# Yemen                             0.475300
# Zambia                            0.800775
# Zimbabwe                          0.627019
# occupied Palestinian territory    0.000000
# Name: RecoveryRate, Length: 229, dtype: float64

# %%
# 17.What is the trend of new confirmed cases over time globally?
df['NewConfirmed'] = df.groupby('Country/Region')['Confirmed'].diff().fillna(0)
new_confirmed_trend = df.groupby('ObservationDate')['NewConfirmed'].sum()
new_confirmed_trend.plot(title='Trend of New Confirmed Cases Over Time Globally')
# Out:
# <Axes: title={'center': 'Trend of New Confirmed Cases Over Time Globally'}, xlabel='ObservationDate'>

# %%
# 18.How does the fatality rate vary across different provinces/states?
df['FatalityRate'] = df['Deaths'] / df['Confirmed']
fatality_rate_by_province = df.groupby('Province/State')['FatalityRate'].mean()
print("Fatality rate by province/state:", fatality_rate_by_province)
# Out:
# Fatality rate by province/state: Province/State
#  Montreal, QC          0.000000
#  Norfolk County, MA    0.000000
# Abruzzo                0.073259
# Acre                   0.021711
# Adygea Republic        0.009184
#                          ...
# Zaporizhia Oblast      0.017735
# Zeeland                0.028329
# Zhejiang               0.000731
# Zhytomyr Oblast        0.018048
# Zuid-Holland           0.029868
# Name: FatalityRate, Length: 736, dtype: float64

# %%
# 19.How does the recovery rate vary across different provinces/states?
df.groupby('Province/State')['RecoveryRate'].mean()
# Out:
# Province/State
#  Montreal, QC          0.000000
#  Norfolk County, MA    0.000000
# Abruzzo                0.682790
# Acre                   0.760418
# Adygea Republic        0.832230
#                          ...
# Zaporizhia Oblast      0.612266
# Zeeland                0.000000
# Zhejiang               0.935524
# Zhytomyr Oblast        0.710896
# Zuid-Holland           0.000000
# Name: RecoveryRate, Length: 736, dtype: float64

# %%
# 20.What is the trend of active cases over time globally?
df['Active'] = df['Confirmed'] - (df['Recovered'] + df['Deaths'])

# Group by date and sum the active cases globally
global_active_trend = df.groupby('ObservationDate')['Active'].sum()

# Plot the trend
plt.figure(figsize=(12, 6))
plt.plot(global_active_trend.index, global_active_trend.values, marker='o', linestyle='-', color='orange')
plt.title('Global Trend of Active COVID-19 Cases Over Time')
plt.xlabel('Date')
plt.ylabel('Number of Active Cases')
plt.grid(True)
